# %% [markdown]
# # Imports

# %%
import os

import torch
import torch_geometric.transforms as T

from torch.utils.data import Dataset

from torch_geometric.datasets import Planetoid, TUDataset
from torch_geometric.loader import NeighborSampler
from torch_geometric.loader import DataLoader

import torch.multiprocessing
torch.multiprocessing.set_sharing_strategy('file_system')

# %%
DATA_PATH = './dataset'
MODEL_PATH = './models'
DEVICE = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %% [markdown]
# # Planetoid - Cora

# %%
dataset = Planetoid(DATA_PATH, "Cora",  transform=T.NormalizeFeatures())

dataset
# Cora()

dataset.num_features
# 1433
# Out:
# 1433

# %%
data = dataset[0]

data
# Data(x=[2708, 1433], edge_index=[2, 10556], y=[2708], train_mask=[2708], val_mask=[2708], test_mask=[2708])

data.num_features
# 1433
# Out:
# 1433

# %%
type(dataset)
# torch_geometric.datasets.planetoid.Planetoid

isinstance(dataset, Dataset)
# True
# Out:
# True

# %%
dataloader = DataLoader(dataset, batch_size=128)

len(dataloader)
# Out:
# 1

# %%
train_loader = NeighborSampler(
    data.edge_index, node_idx=None,
    sizes=[10, 10, 25], batch_size=128,
    shuffle=True, num_workers=8
)
test_loader = NeighborSampler(
    data.edge_index, node_idx=None,
    sizes=[10, 10, 25], batch_size=128,
    shuffle=False, num_workers=8
)

# %%
for i, batch in enumerate(train_loader):
    # print(i)
    if i==0:
        print(batch)
# Out:
# (128, tensor([2342, 1291, 1635,  ..., 2700, 2571, 1018]), [EdgeIndex(edge_index=tensor([[ 128,  129,  130,  ..., 1645,  498, 1243],
#         [   0,    1,    1,  ..., 1243, 1244, 1244]]), e_id=tensor([ 9588,  5014,  5015,  ...,  7732, 10322, 10323]), size=(2010, 1245)), EdgeIndex(edge_index=tensor([[ 128,  129,  130,  ..., 1244,  127, 1243],
#         [   0,    1,    1,  ...,  498,  499,  499]]), e_id=tensor([9588, 5014, 5015,  ..., 3181, 7701, 7702]), size=(1245, 500)), EdgeIndex(edge_index=tensor([[128, 129, 130, 131, 132, 133, 134, 135, 136,  28, 137, 138, 139, 140,
#          141, 142, 143, 144, 145, 146, 147, 148, 149, 150, 151, 152, 153, 154,
#          155, 156, 157, 158, 159, 160, 161, 162,  46, 163, 164, 165, 166, 167,
#          168, 169, 170, 171, 172, 173, 174, 175, 176, 177, 178, 179, 180, 181,
#          182, 183, 184, 185, 186,  79, 185, 187, 188, 189, 190, 191,  87, 192,
#          193, 194, 139, 195, 196, 197, 198, 199, 200, 201, 202, 203, 204, 205,
#          206,   4,  32, 207, 208, 209, 210, 211, 212, 213, 214, 215, 216, 217,
#          218, 219, 220, 221, 222, 223, 224, 225, 226,  28, 134, 207, 227, 228,
#          229, 230, 231, 232, 165, 233, 234, 235, 236, 237, 238, 203, 239, 240,
#          241, 242, 243, 244, 245, 246, 247, 248, 249, 250, 251, 252, 253, 254,
#          255, 256, 257, 258, 259, 260, 261, 262, 263, 264, 265, 266, 267, 268,
#           67, 269, 270, 271, 272, 273, 274, 275,  11, 276, 277, 278, 279, 280,
#          281, 282, 283, 284,  28, 285, 286,  67, 287, 288, 289, 290, 291, 292,
#          293, 165, 143, 294, 129, 196, 259, 295, 296, 138, 297, 298, 299, 300,
#          301, 302, 303, 304, 305, 306, 307, 308, 309, 143, 310, 311,  67, 312,
#          313, 314, 101, 315, 316, 317, 318, 319, 320,  78, 104, 321, 322, 323,
#          324, 325, 326, 170, 327,  44,  48, 287, 328, 329, 330, 331, 332, 333,
#          334, 335, 336, 337, 338, 339, 340, 341, 342, 343, 344, 345, 346, 347,
#          9695,   211,   203,   210,   202,   205,   204,   208,   209,   207,
#           206, 10028, 10029,  8759,  8761,  8755,  8756,  8757,  8758,  8760,
#          8762,  8763,  8764,  1855,  1857,  1854,  1856,  3910,  3911,  3912,
#          3913,  3914,  6025,  6026,  6027,  2761,  2762, 10053,  8543,  8542,
#          8544,   299,   298,   295,   296,   297,   300, 10431, 10430, 10432,
#          7445,  7446,  7447,  7448,  3567,  3568,  8960,  6968,  6967,  6969,
#          6970,  2794,  2223,  2218,  2219,  2220,  2221,  2222,  2631,  2626,
#          2627,  2628,  2629,  2630,  2632,  9290,  9286,  9287,  9288,  9289,
#          9291,  9292,  4611,  4610,  4609,  4612,  1323,  1324,  1569,  1570,
#          1571,  5739,  5740,  7084,  7082,  7083,  7085,  1495,  1496, 10440,
#         10441,  5502,  5503,  3764,  9599,  9600,  9601,  1049,  1050,  1051,
#          1052,  5023,  5024,  9976,  9977,  3626,  3625,  5165,  5166,  5167,
#          1673,  9191,  9188,  9189,  9190,  3570,  3574,  3569,  3571,  3572,
#          3573,  6085,  6086,  6087,  6088, 10193,  8129,  8126,  8128,  8125,
#          8127,  9917,  9918,  1940,  1941,  1942,  1943,  1944,  1945,  1946,
#          1947,  9235, 10171, 10172, 10173,  3620,  9138,  9139,  7875,  7876,
#          7877,  7878,  7879,  6070,  6071,  6072,  6073,  7086,  7088,  7087,
#          9706,   399,   402,   407,   400,   401,   403,   404,   405,   408,
#           409,  1651,  1652,  1653,  1650,  5162,  5163,  5164,  1200,  1197,
#          1198,  1199,  1201,  5472,  5470,  5471,  5473,  5474,  5475,  5476,
#          5477, 10286, 10287,  7678,  7676,  7677,  9724,  9726,  9725,  7697,
#          7698,  7699,  7700]), size=(500, 128))])

# %% [markdown]
# # TUDataset - PTC MR

# %%
dataset = TUDataset(DATA_PATH, name='PTC_MR')

dataset
# PTC_MR(344)

dataset.num_features
# 18
# Out:
# 18

# %%
dataset[0]
# Data(edge_index=[2, 2], x=[2, 18], edge_attr=[2, 4], y=[1])

dataset[1]
# Data(edge_index=[2, 6], x=[4, 18], edge_attr=[6, 4], y=[1])
# Out:
# Data(edge_index=[2, 6], x=[4, 18], edge_attr=[6, 4], y=[1])

# %%
dataloader = DataLoader(dataset, batch_size=128)
len(dataloader)
# Out:
# 3

# %%
for i, batch in enumerate(dataloader):
    print(batch)
# Out:
# DataBatch(edge_index=[2, 3606], x=[1755, 18], edge_attr=[3606, 4], y=[128], batch=[1755], ptr=[129])
# DataBatch(edge_index=[2, 4248], x=[2049, 18], edge_attr=[4248, 4], y=[128], batch=[2049], ptr=[129])
# DataBatch(edge_index=[2, 2254], x=[1111, 18], edge_attr=[2254, 4], y=[88], batch=[1111], ptr=[89])
