# %%
import sys
sys.path.append("../src")

from plotting import cross_augmentation_plot

import os.path as osp
import pandas as pd

OUPUT_FOLDER = "../output"
FIG_FOLDER = "../fig"

# %% [markdown]
# # GraphCL InfoNCE

# %%
result_df = pd.read_csv(osp.join(OUPUT_FOLDER, "augmentation_benchmark_graphcl_infonce.csv"))
result_df["MicroF1"] *= 100
result_df["MacroF1"] *= 100

result_df[(result_df.Aug1 == "NodeDropping") & (result_df.Aug2 == "RWSampling")]
# Out:
#        Data   Method       Archi Mode      Obj  Neg          Aug1  Aug1Strat  \
# 23   PTC_MR  GraphCL  DualBranch  G2G  InfoNCE  NaN  NodeDropping        NaN
# 49   PTC_MR  GraphCL  DualBranch  G2G  InfoNCE  NaN  NodeDropping        NaN
# 75   PTC_MR  GraphCL  DualBranch  G2G  InfoNCE  NaN  NodeDropping        NaN
# 101  PTC_MR  GraphCL  DualBranch  G2G  InfoNCE  NaN  NodeDropping        NaN
# 127  PTC_MR  GraphCL  DualBranch  G2G  InfoNCE  NaN  NodeDropping        NaN
#
#            Aug2 Aug2Strat  MicroF1  MacroF1
# 23   RWSampling       NaN     63.0     62.0
# 49   RWSampling       NaN     51.0     49.0
# 75   RWSampling       NaN     43.0     40.0
# 101  RWSampling       NaN     43.0     43.0
# 127  RWSampling       NaN     60.0     60.0

# %%
product_df = result_df[result_df.Aug2 != "EdgeRemoving, FeatureMasking, NodeDropping, RWSampling"]

grouped_data = product_df.groupby(["Aug1", "Aug2"])["MicroF1"].agg(["mean", "std"]).reset_index()
grouped_data["mean_var_str"] = grouped_data.apply(lambda row: f"{row['mean']:.2f} +/- {row['std']:.2f}", axis=1)
grouped_data.drop(columns=['mean', 'std'], inplace=True)

# %%
cross_augmentation_plot(
    product_df,
    title="G2G contrasting - InfoNCE",
    savefig=osp.join(FIG_FOLDER, "augmentation_benchmark_graphcl_infonce.png"),
)

# %% [markdown]
# # GraphCL - JSD

# %%
result_df = pd.read_csv(osp.join(OUPUT_FOLDER, "augmentation_benchmark_graphcl_jsd.csv"))
result_df["MicroF1"] *= 100
result_df["MacroF1"] *= 100
result_df
# Out:
#        Data   Method       Archi Mode  Obj  Neg          Aug1  Aug1Strat  \
# 0    PTC_MR  GraphCL  DualBranch  G2G  JSD  NaN      Identity        NaN
# 1    PTC_MR  GraphCL  DualBranch  G2G  JSD  NaN      Identity        NaN
# 2    PTC_MR  GraphCL  DualBranch  G2G  JSD  NaN      Identity        NaN
# 3    PTC_MR  GraphCL  DualBranch  G2G  JSD  NaN      Identity        NaN
# 4    PTC_MR  GraphCL  DualBranch  G2G  JSD  NaN      Identity        NaN
# ..      ...      ...         ...  ...  ...  ...           ...        ...
# 125  PTC_MR  GraphCL  DualBranch  G2G  JSD  NaN  NodeDropping        NaN
# 126  PTC_MR  GraphCL  DualBranch  G2G  JSD  NaN  NodeDropping        NaN
# 127  PTC_MR  GraphCL  DualBranch  G2G  JSD  NaN  NodeDropping        NaN
# 128  PTC_MR  GraphCL  DualBranch  G2G  JSD  NaN  NodeDropping        NaN
# 129  PTC_MR  GraphCL  DualBranch  G2G  JSD  NaN      Identity        NaN
#
#                                                   Aug2 Aug2Strat  MicroF1  \
# 0                                             Identity       NaN     63.0
# 1                                       FeatureMasking       NaN     51.0
# 2                                         EdgeRemoving       NaN     57.0
# 3                                           RWSampling       NaN     66.0
# 4                                         NodeDropping       NaN     54.0
# ..                                                 ...       ...      ...
# 125                                     FeatureMasking       NaN     69.0
# 126                                       EdgeRemoving       NaN     51.0
# 127                                         RWSampling       NaN     54.0
# 128                                       NodeDropping       NaN     69.0
# 129  EdgeRemoving, FeatureMasking, NodeDropping, RW...    Random     54.0
#
#      MacroF1
# 0       62.0
# 1       47.0
# 2       57.0
# 3       63.0
# 4       53.0
# ..       ...
# 125     66.0
# 126     50.0
# 127     54.0
# 128     64.0
# 129     44.0
#
# [130 rows x 12 columns]

# %%
product_df = result_df[result_df.Aug2 != "EdgeRemoving, FeatureMasking, NodeDropping, RWSampling"]

# %%
cross_augmentation_plot(
    product_df,
    title="G2G contrasting - JSD",
    savefig=osp.join(FIG_FOLDER, "augmentation_benchmark_graphcl_jsd.png"),
)

# %% [markdown]
# # GraphCL - BootstrapLatent

# %%
result_df = pd.read_csv(osp.join(OUPUT_FOLDER, "augmentation_benchmark_graphcl_bootstrap.csv"))
result_df["MicroF1"] *= 100
result_df["MacroF1"] *= 100
result_df
# Out:
#        Data   Method       Archi Mode              Obj  Neg          Aug1  \
# 0    PTC_MR  GraphCL  DualBranch  G2G  BootstrapLatent  NaN      Identity
# 1    PTC_MR  GraphCL  DualBranch  G2G  BootstrapLatent  NaN      Identity
# 2    PTC_MR  GraphCL  DualBranch  G2G  BootstrapLatent  NaN      Identity
# 3    PTC_MR  GraphCL  DualBranch  G2G  BootstrapLatent  NaN      Identity
# 4    PTC_MR  GraphCL  DualBranch  G2G  BootstrapLatent  NaN      Identity
# ..      ...      ...         ...  ...              ...  ...           ...
# 125  PTC_MR  GraphCL  DualBranch  G2G  BootstrapLatent  NaN  NodeDropping
# 126  PTC_MR  GraphCL  DualBranch  G2G  BootstrapLatent  NaN  NodeDropping
# 127  PTC_MR  GraphCL  DualBranch  G2G  BootstrapLatent  NaN  NodeDropping
# 128  PTC_MR  GraphCL  DualBranch  G2G  BootstrapLatent  NaN  NodeDropping
# 129  PTC_MR  GraphCL  DualBranch  G2G  BootstrapLatent  NaN      Identity
#
#      Aug1Strat                                               Aug2 Aug2Strat  \
# 0          NaN                                           Identity       NaN
# 1          NaN                                     FeatureMasking       NaN
# 2          NaN                                       EdgeRemoving       NaN
# 3          NaN                                         RWSampling       NaN
# 4          NaN                                       NodeDropping       NaN
# ..         ...                                                ...       ...
# 125        NaN                                     FeatureMasking       NaN
# 126        NaN                                       EdgeRemoving       NaN
# 127        NaN                                         RWSampling       NaN
# 128        NaN                                       NodeDropping       NaN
# 129        NaN  EdgeRemoving, FeatureMasking, NodeDropping, RW...    Random
#
#      MicroF1  MacroF1
# 0       57.0     57.0
# 1       49.0     46.0
# 2       37.0     36.0
# 3       60.0     51.0
# 4       63.0     39.0
# ..       ...      ...
# 125     49.0     33.0
# 126     57.0     36.0
# 127     60.0     60.0
# 128     54.0     47.0
# 129     66.0     55.0
#
# [130 rows x 12 columns]

# %%
product_df = result_df[result_df.Aug2 != "EdgeRemoving, FeatureMasking, NodeDropping, RWSampling"]

# %%
cross_augmentation_plot(
    product_df,
    title="G2G contrasting - BootstrapLatent",
    savefig=osp.join(FIG_FOLDER, "augmentation_benchmark_graphcl_bootstrap.png"),
)

# %% [markdown]
# # GraphCL - BarlowTwins

# %%
result_df = pd.read_csv(osp.join(OUPUT_FOLDER, "augmentation_benchmark_graphcl_barlow.csv"))
result_df["MicroF1"] *= 100
result_df["MacroF1"] *= 100
result_df
# Out:
#        Data   Method       Archi Mode          Obj  Neg          Aug1  \
# 0    PTC_MR  GraphCL  DualBranch  G2G  BarlowTwins  NaN      Identity
# 1    PTC_MR  GraphCL  DualBranch  G2G  BarlowTwins  NaN      Identity
# 2    PTC_MR  GraphCL  DualBranch  G2G  BarlowTwins  NaN      Identity
# 3    PTC_MR  GraphCL  DualBranch  G2G  BarlowTwins  NaN      Identity
# 4    PTC_MR  GraphCL  DualBranch  G2G  BarlowTwins  NaN      Identity
# ..      ...      ...         ...  ...          ...  ...           ...
# 125  PTC_MR  GraphCL  DualBranch  G2G  BarlowTwins  NaN  NodeDropping
# 126  PTC_MR  GraphCL  DualBranch  G2G  BarlowTwins  NaN  NodeDropping
# 127  PTC_MR  GraphCL  DualBranch  G2G  BarlowTwins  NaN  NodeDropping
# 128  PTC_MR  GraphCL  DualBranch  G2G  BarlowTwins  NaN  NodeDropping
# 129  PTC_MR  GraphCL  DualBranch  G2G  BarlowTwins  NaN      Identity
#
#      Aug1Strat                                               Aug2 Aug2Strat  \
# 0          NaN                                           Identity       NaN
# 1          NaN                                     FeatureMasking       NaN
# 2          NaN                                       EdgeRemoving       NaN
# 3          NaN                                         RWSampling       NaN
# 4          NaN                                       NodeDropping       NaN
# ..         ...                                                ...       ...
# 125        NaN                                     FeatureMasking       NaN
# 126        NaN                                       EdgeRemoving       NaN
# 127        NaN                                         RWSampling       NaN
# 128        NaN                                       NodeDropping       NaN
# 129        NaN  EdgeRemoving, FeatureMasking, NodeDropping, RW...    Random
#
#      MicroF1  MacroF1
# 0       63.0     61.0
# 1       69.0     68.0
# 2       54.0     53.0
# 3       51.0     51.0
# 4       80.0     80.0
# ..       ...      ...
# 125     57.0     57.0
# 126     60.0     57.0
# 127     60.0     59.0
# 128     57.0     46.0
# 129     54.0     54.0
#
# [130 rows x 12 columns]

# %%
product_df = result_df[result_df.Aug2 != "EdgeRemoving, FeatureMasking, NodeDropping, RWSampling"]

# %%
cross_augmentation_plot(
    product_df,
    title="G2G contrasting - BarlowTwins",
    savefig=osp.join(FIG_FOLDER, "augmentation_benchmark_graphcl_barlow.png"),
)
